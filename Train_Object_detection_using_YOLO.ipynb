# %% [markdown]
# <a href="https://colab.research.google.com/github/SURYA-MANUSANI/Traffic-Sign-Detection_Using-Yolo/blob/main/Train_Object_detection_using_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install the YOLO-8
# !pip install ultralytics==8.3.133
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %%
#Import dataset from Roboflow

# %pwd
# Out:
# '/content'

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection

# %%
path = "/content/RoadSignDetection"

# %%
# %pwd
# Out:
# '/content'

# %%
os.chdir("/content/RoadSignDetection")
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YlL9tms5Z6hDMxVbZO6m")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:01<00:00, 9535.91it/s]

# %%
os.chdir("/content/RoadSignDetection/Self-Driving-Cars-6")

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/Self-Driving-Cars-6'

# %%
#Train the YOLOv8 over a Custom Dataset

# !yolo task=detect mode=train model=yolov8n.pt data=/content/RoadSignDetection/Self-Driving-Cars-6/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 122MB/s]
# New https://pypi.org/project/ultralytics/8.3.135 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls '/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train'
# Out:
# args.yaml			 PR_curve.png	   val_batch0_labels.jpg
# confusion_matrix_normalized.png  R_curve.png	   val_batch0_pred.jpg
# confusion_matrix.png		 results.csv	   val_batch1_labels.jpg
# F1_curve.png			 results.png	   val_batch1_pred.jpg
# labels_correlogram.jpg		 train_batch0.jpg  val_batch2_labels.jpg
# labels.jpg			 train_batch1.jpg  val_batch2_pred.jpg
# P_curve.png			 train_batch2.jpg  weights

# %%
from IPython.display import Image, display
Image(filename='/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image, display
Image(filename='/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/results.png')

# %%
import pandas as pd

df = pd.read_csv('/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/results.csv')

print(df.tail(1))
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 9     10  641.005         0.55286         0.74144         0.93778
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 9               0.92423            0.82739           0.91586
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 9              0.78578       0.60419       0.53984       0.95787  0.000057
#
#      lr/pg1    lr/pg2
# 9  0.000057  0.000057

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/Self-Driving-Cars-6'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
mkdir ManualTestingData

# %%
os.chdir("/content/ManualTestingData")

# %%
# %pwd
# Out:
# '/content/ManualTestingData'

# %%
URL = 'https://drive.google.com/file/d/11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH/view?usp=sharing'

id = '11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH' -O 'inputVideo1.mp4'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH' -O 'inputVideo1.mp4'
# Out:
# --2025-05-15 22:02:29--  https://docs.google.com/uc?export=download&id=11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH
# Resolving docs.google.com (docs.google.com)... 74.125.137.101, 74.125.137.102, 74.125.137.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.137.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH&export=download [following]
# --2025-05-15 22:02:29--  https://drive.usercontent.google.com/download?id=11_fYYvXJ0T9BVePuQ0osYNDEvi053uvH&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.101.132, 2607:f8b0:4023:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.101.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728449 (711K) [video/mp4]
# Saving to: ‘inputVideo1.mp4’
#
# ...

# %%
# !yolo task=detect mode=predict model =/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/weights/best.pt conf=.25 source = inputVideo1.mp4 save = True
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 67.1ms
# video 1/1 (frame 2/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 3/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 4/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (frame 5/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 6/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 7/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 8.7ms
# video 1/1 (frame 8/56) /content/ManualTestingData/inputVideo1.mp4: 384x640 (no detections), 15.0ms
# ...

# %%
URL = 'https://drive.google.com/file/d/1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz/view?usp=sharing'

id = '1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz' -O 'inputVideo2.mp4'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz' -O 'inputVideo2.mp4'
# Out:
# --2025-05-15 22:17:16--  https://docs.google.com/uc?export=download&id=1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz
# Resolving docs.google.com (docs.google.com)... 142.251.2.100, 142.251.2.101, 142.251.2.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz&export=download [following]
# --2025-05-15 22:17:16--  https://drive.usercontent.google.com/download?id=1sdWE2i7KoR9YMMAQEzExIpRU9CQMJrjz&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.101.132, 2607:f8b0:4023:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.101.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1130446 (1.1M) [video/mp4]
# Saving to: ‘inputVideo2.mp4’
#
# ...

# %%
# !yolo task=detect mode=predict model =/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/weights/best.pt conf=.25 source = inputVideo2.mp4 save = True
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 44.1ms
# video 1/1 (frame 2/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.7ms
# video 1/1 (frame 3/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.2ms
# video 1/1 (frame 4/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.2ms
# video 1/1 (frame 5/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.3ms
# video 1/1 (frame 6/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.1ms
# video 1/1 (frame 7/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 6.0ms
# video 1/1 (frame 8/777) /content/ManualTestingData/inputVideo2.mp4: 384x640 1 Red Light, 8.3ms
# ...

# %%
URL = 'https://drive.google.com/file/d/1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1/view?usp=sharing'

id = '1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1' -O 'photo.jpg'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1' -O 'photo.jpg'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1' -O 'photo.jpg'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1' -O 'photo.jpg'
# Out:
# --2025-05-15 22:23:34--  https://docs.google.com/uc?export=download&id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1
# Resolving docs.google.com (docs.google.com)... 142.250.101.138, 142.250.101.102, 142.250.101.139, ...
# Connecting to docs.google.com (docs.google.com)|142.250.101.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1&export=download [following]
# --2025-05-15 22:23:34--  https://drive.usercontent.google.com/download?id=1RP7TWqAu_N8UamMQMDjyAqryPrpcwyi1&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.101.132, 2607:f8b0:4023:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.101.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12027 (12K) [image/jpeg]
# Saving to: ‘photo.jpg’
#
# ...

# %%
# !yolo task=detect mode=predict model =/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train/weights/best.pt conf=.25 source = photo.jpg save = True
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/ManualTestingData/photo.jpg: 480x640 2 Green Lights, 1 Red Light, 36.5ms
# Speed: 3.8ms preprocess, 36.5ms inference, 150.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files

files.download('/content/ManualTestingData/runs/detect/predict2/inputVideo1.avi')
files.download('/content/ManualTestingData/runs/detect/predict3/inputVideo2.avi')
files.download('/content/ManualTestingData/runs/detect/predict4/photo.jpg')
